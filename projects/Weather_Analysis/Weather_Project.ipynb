# %% [markdown]
# ## Weather project

# %%
import pandas as pd

# %%
df = pd.read_csv("Project 1 - Weather Dataset.csv")
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# ## Q)1.Find the unique 'Wind Speed ' Values in the data

# %%
df.columns # it is return the columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %%
df['Wind Speed_km/h'].nunique()
# Out:
# 34

# %% [markdown]
# ### Weather data bar

# %%
df['Weather'].value_counts().head(5).plot(kind = "bar"); # Value_count return the number of counts

# %%
df[df['Weather']=="Clear"].shape[0] # Shape that return the count of the Weather project that value is %clear
# Out:
# 1326

# %%
df[df["Wind Speed_km/h"]==4]  # That return the  wind speed which is equal to the 4
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 96       1/5/2012 0:00    -8.8             -11.7         79                4
# 101      1/5/2012 5:00    -7.0              -9.5         82                4
# 146      1/7/2012 2:00    -8.1             -11.1         79                4
# ...                ...     ...               ...        ...              ...
# 8768   12/31/2012 8:00    -8.6             -10.3         87                4
# 8769   12/31/2012 9:00    -8.1              -9.6         89                4
# 8770  12/31/2012 10:00    -7.4              -8.9         89                4
# 8772  12/31/2012 12:00    -5.8              -7.5         88                4
# 8773  12/31/2012 13:00    -4.6              -6.6         86                4
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# ### Q4. Find out all the Null values in the data

# %%
df.isnull().sum() # it return the null value counts
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# ### Q5 . Rename theh colomns name "Weather "to "Weather_Condition"

# %%
df.rename(columns={"Weather" : "Weather_Condition"},inplace=True) # df. rename is method rename the coloumns

# %%
df.columns # new columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_Condition'],
#       dtype='object')

# %% [markdown]
# ### Q5 . What the avarge visiblity

# %%
sum(df['Visibility_km'])/len(df["Visibility_km"]) # avrage calculte the value
# Out:
# 27.664446721311474

# %%
df.Visibility_km.mean() # return the means
# Out:
# np.float64(27.664446721311474)

# %% [markdown]
# ### Q8  Find all instance when wind spaced above 24

# %%
df[(df["Wind Speed_km/h"]>24) & (df["Visibility_km"]==25)] # here  i do find the wind speed which above the 24 and 25
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23      1/1/2012 23:00     5.3               2.0         79               30
# 24       1/2/2012 0:00     5.2               1.5         77               35
# 25       1/2/2012 1:00     4.6               0.0         72               39
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# ...                ...     ...               ...        ...              ...
# 8705  12/28/2012 17:00    -8.6             -12.0         76               26
# 8753  12/30/2012 17:00   -12.1             -15.8         74               28
# 8755  12/30/2012 19:00   -13.4             -16.5         77               26
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8760   12/31/2012 0:00   -11.1             -14.4         77               26
#
# ...

# %% [markdown]
# ### Avarge data for weather condition

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_Condition'],
#       dtype='object')

# %%
df[df["Weather_Condition"] == "Cloudy"]["Temp_C"].mean()
# Out:
# np.float64(7.970543981481482)

# %%
df[df["Weather_Condition"] == input()]["Temp_C"].mean()
# Out:
#  Rain
# np.float64(9.78627450980392)

# %%
df.groupby('Weather_Condition').mean("numeric_only")
# Out:
#                                             Temp_C  Dew Point Temp_C  \
# Weather_Condition
# Clear                                     6.825716          0.089367
# Cloudy                                    7.970544          2.375810
# Drizzle                                   7.353659          5.504878
# Drizzle,Fog                               8.067500          7.033750
# Drizzle,Ice Pellets,Fog                   0.400000         -0.700000
# Drizzle,Snow                              1.050000          0.150000
# Drizzle,Snow,Fog                          0.693333          0.120000
# Fog                                       4.303333          3.159333
# Freezing Drizzle                         -5.657143         -8.000000
# Freezing Drizzle,Fog                     -2.533333         -4.183333
# Freezing Drizzle,Haze                    -5.433333         -8.000000
# Freezing Drizzle,Snow                    -5.109091         -7.072727
# ...

# %% [markdown]
# ### What is the minimum & maximum value of each column agains each "Weather condition ?"

# %%
df.groupby("Weather_Condition").agg(['min','max'])
# Out:
#                                                 Date/Time                    \
#                                                       min               max
# Weather_Condition
# Clear                                      1/11/2012 1:00     9/9/2012 5:00
# Cloudy                                     1/1/2012 17:00    9/9/2012 23:00
# Drizzle                                   1/23/2012 21:00    9/30/2012 3:00
# Drizzle,Fog                               1/23/2012 20:00    9/30/2012 2:00
# Drizzle,Ice Pellets,Fog                   12/17/2012 9:00   12/17/2012 9:00
# Drizzle,Snow                             12/17/2012 15:00  12/19/2012 18:00
# Drizzle,Snow,Fog                         12/18/2012 21:00   12/22/2012 3:00
# Fog                                         1/1/2012 0:00    9/22/2012 0:00
# Freezing Drizzle                          1/13/2012 10:00     2/1/2012 5:00
# Freezing Drizzle,Fog                        1/1/2012 2:00   12/10/2012 5:00
# ...

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather_Condition'],
#       dtype='object')

# %% [markdown]
# ### Q12 Find all instancge is clear or visiblity is above 4
